# %% [markdown]
# [![AnalyticsDojo](https://s3.amazonaws.com/analyticsdojo/logo/final-logo.png)](http://www.analyticsdojo.com)
# <center><h1>Introduction to Python - Test Local Jupyter Notebook</h1></center>
# <center><h3><a href = 'http://www.analyticsdojo.com'>www.analyticsdojo.com</a></h3></center>

# %% [markdown]
# ### Links: [local](http://localhost:8888/notebooks/classes/01-overview/local-intro.ipynb) [github](https://github.com/AnalyticsDojo/materials/blob/master/analyticsdojo/classes/01-overview/local-intro.ipynb) [slides](http://nbviewer.jupyter.org/format/slides/github/AnalyticsDojo/materials/blob/master/analyticsdojo/classes/01-overview/local-intro.ipynb#/)

# %% [markdown]
# ## Test Notebook
#
# The goal of this notebook is to simply test the Python version and to show how to interact with a local data file. It can be used when running Jupyter either from Docker or with Anaconda.

# %%
#Press play to run this command.  It should indicate that at least Python version 3 is running. 
import sys
print("The Python version is %s.%s.%s" % sys.version_info[:3])
# Out:
# The Python version is 3.5.2

# %% [markdown]
# ## Local Python Version
# - Your local Python version should indicate greater than 3.0.
# - If it indicates 2.X and you are using Anaconda, then (and only then) you should execute the following commands from a command line.
# ```
# conda create -n py3k python=3 anaconda
# source activate py3k
# ```
# - After entering those commands, restart jupyter and activate the py3k Kernel for this notebook by selecting *Kernel->Change kernel->Python[py3k]*

# %%
# This will load the local iris.csv file into a Pandas dataframe.  We will work with these a lot in the future.
import pandas as pd
frame = pd.read_csv('../../data/iris.csv')

# %%
import pandas as pd
frame = pd.read_csv('/home/jovyan/work/data/iris.csv')

# %%
# !pwd
# Out:
# /home/jovyan/work/classes/01-overview

# %%
# This will print out the dataframe.
frame
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# 5            5.4         3.9          1.7         0.4     setosa
# 6            4.6         3.4          1.4         0.3     setosa
# 7            5.0         3.4          1.5         0.2     setosa
# 8            4.4         2.9          1.4         0.2     setosa
# 9            4.9         3.1          1.5         0.1     setosa
# 10           5.4         3.7          1.5         0.2     setosa
# 11           4.8         3.4          1.6         0.2     setosa
# 12           4.8         3.0          1.4         0.1     setosa
# ...

# %%
#Notice we can't see all of the rows.  Let's change the display.max_rows option so we can all rows. 
pd.set_option('display.max_rows', 500)
frame
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth     species
# 0            5.1         3.5          1.4         0.2      setosa
# 1            4.9         3.0          1.4         0.2      setosa
# 2            4.7         3.2          1.3         0.2      setosa
# 3            4.6         3.1          1.5         0.2      setosa
# 4            5.0         3.6          1.4         0.2      setosa
# 5            5.4         3.9          1.7         0.4      setosa
# 6            4.6         3.4          1.4         0.3      setosa
# 7            5.0         3.4          1.5         0.2      setosa
# 8            4.4         2.9          1.4         0.2      setosa
# 9            4.9         3.1          1.5         0.1      setosa
# 10           5.4         3.7          1.5         0.2      setosa
# 11           4.8         3.4          1.6         0.2      setosa
# 12           4.8         3.0          1.4         0.1      setosa
# ...

# %% [markdown]
# ### CREDITS
#
# Copyright [AnalyticsDojo](http://www.analyticsdojo.com) 2016.
# This work is licensed under the [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0/) license agreement.
