# %% [markdown]
# [![AnalyticsDojo](https://s3.amazonaws.com/analyticsdojo/logo/final-logo.png)](http://www.analyticsdojo.com)
# <center><h1>Introduction to API's with Python</h1></center>
# <center><h3><a href = 'http://www.analyticsdojo.com'>www.analyticsdojo.com</a></h3></center>

# %% [markdown]
# This is adopted from [Mining the Social Web, 2nd Edition](http://bit.ly/16kGNyb)
# Copyright (c) 2013, Matthew A. Russell
# All rights reserved.
#
# This work is licensed under the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt).

# %% [markdown]
# ## Step1.  Authorizing an application to access Twitter account data
#
# You have gone through the process of creating an application.  Now let's

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
#     100% |████████████████████████████████| 61kB 743kB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = ''
CONSUMER_SECRET =''
OAUTH_TOKEN = ''
OAUTH_TOKEN_SECRET = ''

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print (twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7fd95c420c88>

# %% [markdown]
# The outcoming of running the above API is to generate a twitter object.

# %% [markdown]
# ## Step 2. Getting Help

# %%
# We can get some help on how to use the twitter api with the following. 
help(twitter)
# Out:
# Help on package twitter:
#
# NAME
#     twitter - The minimalist yet fully featured Twitter API and Python toolset.
#
# DESCRIPTION
#     The Twitter and TwitterStream classes are the key to building your own
#     Twitter-enabled applications.
#
#
#     The Twitter class
#     -----------------
#
#     The minimalist yet fully featured Twitter API class.
#
#     Get RESTful data by accessing members of this class. The result
#     is decoded python objects (lists and dicts).
#
#     The Twitter API is documented at:
#
#       http://dev.twitter.com/doc
#
#
#     Examples::
#
#         from twitter import *
#
#         t = Twitter(
#             auth=OAuth(token, token_key, con_secret, con_secret_key))
#
#         # Get your "home" timeline
#         t.statuses.home_timeline()
#
#         # Get a particular friend's timeline
#         t.statuses.user_timeline(screen_name="billybob")
#
#         # to pass in GET/POST parameters, such as `count`
#         t.statuses.home_timeline(count=5)
#
#         # to pass in the GET/POST parameter `id` you need to use `_id`
#         t.statuses.oembed(_id=1234567890)
#
#         # Update your status
#         t.statuses.update(
#             status="Using @sixohsix's sweet Python Twitter Tools.")
#
#         # Send a direct message
#         t.direct_messages.new(
#             user="billybob",
#             text="I think yer swell!")
#
#         # Get the members of tamtar's list "Things That Are Rad"
#         t.lists.members(owner_screen_name="tamtar", slug="things-that-are-rad")
#
#         # An *optional* `_timeout` parameter can also be used for API
#         # calls which take much more time than normal or twitter stops
#         # responding for some reason:
#         t.users.lookup(
#             screen_name=','.join(A_LIST_OF_100_SCREEN_NAMES),             _timeout=1)
#
#         # Overriding Method: GET/POST
#         # you should not need to use this method as this library properly
#         # detects whether GET or POST should be used, Nevertheless
#         # to force a particular method, use `_method`
#         t.statuses.oembed(_id=1234567890, _method='GET')
#
#         # Send images along with your tweets:
#         # - first just read images from the web or from files the regular way:
#         with open("example.png", "rb") as imagefile:
#             imagedata = imagefile.read()
#         # - then upload medias one by one on Twitter's dedicated server
#         #   and collect each one's id:
#         t_up = Twitter(domain='upload.twitter.com',
#             auth=OAuth(token, token_key, con_secret, con_secret_key))
#         id_img1 = t_up.media.upload(media=imagedata)["media_id_string"]
#         id_img2 = t_up.media.upload(media=imagedata)["media_id_string"]
#
#         # - finally send your tweet with the list of media ids:
#         t.statuses.update(status="PTT ★", media_ids=",".join([id_img1, id_img2]))
#
#         # Or send a tweet with an image (or set a logo/banner similarily)
#         # using the old deprecated method that will probably disappear some day
#         params = {"media[]": imagedata, "status": "PTT ★"}
#         # Or for an image encoded as base64:
#         params = {"media[]": base64_image, "status": "PTT ★", "_base64": True}
#         t.statuses.update_with_media(**params)
#
#
#
#     Searching Twitter::
#
#         # Search for the latest tweets about #pycon
#         t.search.tweets(q="#pycon")
#
#
#     Using the data returned
#     -----------------------
#
#     Twitter API calls return decoded JSON. This is converted into
#     a bunch of Python lists, dicts, ints, and strings. For example::
#
#         x = twitter.statuses.home_timeline()
#
#         # The first 'tweet' in the timeline
#         x[0]
#
#         # The screen name of the user who wrote the first 'tweet'
#         x[0]['user']['screen_name']
#
#
#     Getting raw XML data
#     --------------------
#
#     If you prefer to get your Twitter data in XML format, pass
#     format="xml" to the Twitter object when you instantiate it::
#
#         twitter = Twitter(format="xml")
#
#     The output will not be parsed in any way. It will be a raw string
#     of XML.
#
#
#     The TwitterStream class
#     -----------------------
#
#     The TwitterStream object is an interface to the Twitter Stream
#     API. This can be used pretty much the same as the Twitter class
#     except the result of calling a method will be an iterator that
#     yields objects decoded from the stream. For example::
#
#         twitter_stream = TwitterStream(auth=OAuth(...))
#         iterator = twitter_stream.statuses.sample()
#
#         for tweet in iterator:
#             # ...do something with this tweet...
#
#     Per default the ``TwitterStream`` object uses
#     [public streams](https://dev.twitter.com/docs/streaming-apis/streams/public).
#     If you want to use one of the other
#     [streaming APIs](https://dev.twitter.com/docs/streaming-apis), specify the URL
#     manually:
#
#     - [Public streams](https://dev.twitter.com/docs/streaming-apis/streams/public): stream.twitter.com
#     - [User streams](https://dev.twitter.com/docs/streaming-apis/streams/user): userstream.twitter.com
#     - [Site streams](https://dev.twitter.com/docs/streaming-apis/streams/site): sitestream.twitter.com
#
#     Note that you require the proper
#     [permissions](https://dev.twitter.com/docs/application-permission-model) to
#     access these streams. E.g. for direct messages your
#     [application](https://dev.twitter.com/apps) needs the "Read, Write & Direct
#     Messages" permission.
#
#     The following example demonstrates how to retrieve all new direct messages
#     from the user stream::
#
#         auth = OAuth(
#             consumer_key='[your consumer key]',
#             consumer_secret='[your consumer secret]',
#             token='[your token]',
#             token_secret='[your token secret]'
#         )
#         twitter_userstream = TwitterStream(auth=auth, domain='userstream.twitter.com')
#         for msg in twitter_userstream.user():
#             if 'direct_message' in msg:
#                 print msg['direct_message']['text']
#
#     The iterator will yield until the TCP connection breaks. When the
#     connection breaks, the iterator yields `{'hangup': True}`, and
#     raises `StopIteration` if iterated again.
#
#     Similarly, if the stream does not produce heartbeats for more than
#     90 seconds, the iterator yields `{'hangup': True,
#     'heartbeat_timeout': True}`, and raises `StopIteration` if
#     iterated again.
#
#     The `timeout` parameter controls the maximum time between
#     yields. If it is nonzero, then the iterator will yield either
#     stream data or `{'timeout': True}` within the timeout period. This
#     is useful if you want your program to do other stuff in between
#     waiting for tweets.
#
#     The `block` parameter sets the stream to be fully non-blocking. In
#     this mode, the iterator always yields immediately. It returns
#     stream data, or `None`. Note that `timeout` supercedes this
#     argument, so it should also be set `None` to use this mode.
#
#     Twitter Response Objects
#     ------------------------
#
#     Response from a twitter request. Behaves like a list or a string
#     (depending on requested format) but it has a few other interesting
#     attributes.
#
#     `headers` gives you access to the response headers as an
#     httplib.HTTPHeaders instance. You can do
#     `response.headers.get('h')` to retrieve a header.
#
#     Authentication
#     --------------
#
#     You can authenticate with Twitter in three ways: NoAuth, OAuth, or
#     OAuth2 (app-only). Get help() on these classes to learn how to use them.
#
#     OAuth and OAuth2 are probably the most useful.
#
#
#     Working with OAuth
#     ------------------
#
#     Visit the Twitter developer page and create a new application:
#
#         https://dev.twitter.com/apps/new
#
#     This will get you a CONSUMER_KEY and CONSUMER_SECRET.
#
#     When users run your application they have to authenticate your app
#     with their Twitter account. A few HTTP calls to twitter are required
#     to do this. Please see the twitter.oauth_dance module to see how this
#     is done. If you are making a command-line app, you can use the
#     oauth_dance() function directly.
#
#     Performing the "oauth dance" gets you an ouath token and oauth secret
#     that authenticate the user with Twitter. You should save these for
#     later so that the user doesn't have to do the oauth dance again.
#
#     read_token_file and write_token_file are utility methods to read and
#     write OAuth token and secret key values. The values are stored as
#     strings in the file. Not terribly exciting.
#
#     Finally, you can use the OAuth authenticator to connect to Twitter. In
#     code it all goes like this::
#
#         from twitter import *
#
#         MY_TWITTER_CREDS = os.path.expanduser('~/.my_app_credentials')
#         if not os.path.exists(MY_TWITTER_CREDS):
#             oauth_dance("My App Name", CONSUMER_KEY, CONSUMER_SECRET,
#                         MY_TWITTER_CREDS)
#
#         oauth_token, oauth_secret = read_token_file(MY_TWITTER_CREDS)
#
#         twitter = Twitter(auth=OAuth(
#             oauth_token, oauth_token_secret, CONSUMER_KEY, CONSUMER_SECRET))
#
#         # Now work with Twitter
#         twitter.statuses.update(status='Hello, world!')
#
#
#     Working with OAuth2
#     -------------------
#
#     Twitter only supports the application-only flow of OAuth2 for certain
#     API endpoints. This OAuth2 authenticator only supports the application-only
#     flow right now.
#
#     To authenticate with OAuth2, visit the Twitter developer page and create a new
#     application:
#
#         https://dev.twitter.com/apps/new
#
#     This will get you a CONSUMER_KEY and CONSUMER_SECRET.
#
#     Exchange your CONSUMER_KEY and CONSUMER_SECRET for a bearer token using the
#     oauth2_dance function.
#
#     Finally, you can use the OAuth2 authenticator and your bearer token to connect
#     to Twitter. In code it goes like this::
#
#         twitter = Twitter(auth=OAuth2(bearer_token=BEARER_TOKEN))
#
#         # Now work with Twitter
#         twitter.search.tweets(q='keyword')
#
# PACKAGE CONTENTS
#     ansi
#     api
#     archiver
#     auth
#     cmdline
#     follow
#     ircbot
#     logger
#     oauth
#     oauth2
#     oauth_dance
#     stream
#     stream_example
#     timezones
#     twitter_globals
#     util
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         twitter.api.TwitterError
#             twitter.api.TwitterHTTPError
#     builtins.object
#         twitter.api.TwitterResponse
#     twitter.api.TwitterCall(builtins.object)
#         twitter.api.Twitter
#         twitter.stream.TwitterStream
#     twitter.auth.Auth(builtins.object)
#         twitter.auth.NoAuth
#         twitter.auth.UserPassAuth
#         twitter.oauth.OAuth
#         twitter.oauth2.OAuth2
#
#     class NoAuth(Auth)
#      |  No authentication authenticator.
#      |
#      |  Method resolution order:
#      |      NoAuth
#      |      Auth
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  encode_params(self, base_url, method, params)
#      |      Encodes parameters for a request suitable for including in a URL
#      |      or POST body.  This method may also add new params to the request
#      |      if required by the authentication scheme in use.
#      |
#      |  generate_headers(self)
#      |      Generates headers which should be added to the request if required
#      |      by the authentication scheme in use.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Auth:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class OAuth(twitter.auth.Auth)
#      |  An OAuth authenticator.
#      |
#      |  Method resolution order:
#      |      OAuth
#      |      twitter.auth.Auth
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, token, token_secret, consumer_key, consumer_secret)
#      |      Create the authenticator. If you are in the initial stages of
#      |      the OAuth dance and don't yet have a token or token_secret,
#      |      pass empty strings for these params.
#      |
#      |  encode_params(self, base_url, method, params)
#      |      Encodes parameters for a request suitable for including in a URL
#      |      or POST body.  This method may also add new params to the request
#      |      if required by the authentication scheme in use.
#      |
#      |  generate_headers(self)
#      |      Generates headers which should be added to the request if required
#      |      by the authentication scheme in use.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from twitter.auth.Auth:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class OAuth2(twitter.auth.Auth)
#      |  An OAuth2 application-only authenticator.
#      |
#      |  Method resolution order:
#      |      OAuth2
#      |      twitter.auth.Auth
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, consumer_key=None, consumer_secret=None, bearer_token=None)
#      |      Create an authenticator. You can supply consumer_key and
#      |      consumer_secret if you are requesting a bearer_token. Otherwise
#      |      you must supply the bearer_token.
#      |
#      |  encode_params(self, base_url, method, params)
#      |      Encodes parameters for a request suitable for including in a URL
#      |      or POST body.  This method may also add new params to the request
#      |      if required by the authentication scheme in use.
#      |
#      |  generate_headers(self)
#      |      Generates headers which should be added to the request if required
#      |      by the authentication scheme in use.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from twitter.auth.Auth:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Twitter(TwitterCall)
#      |  The minimalist yet fully featured Twitter API class.
#      |
#      |  Get RESTful data by accessing members of this class. The result
#      |  is decoded python objects (lists and dicts).
#      |
#      |  The Twitter API is documented at:
#      |
#      |    http://dev.twitter.com/doc
#      |
#      |
#      |  Examples::
#      |
#      |      from twitter import *
#      |
#      |      t = Twitter(
#      |          auth=OAuth(token, token_key, con_secret, con_secret_key))
#      |
#      |      # Get your "home" timeline
#      |      t.statuses.home_timeline()
#      |
#      |      # Get a particular friend's timeline
#      |      t.statuses.user_timeline(screen_name="billybob")
#      |
#      |      # to pass in GET/POST parameters, such as `count`
#      |      t.statuses.home_timeline(count=5)
#      |
#      |      # to pass in the GET/POST parameter `id` you need to use `_id`
#      |      t.statuses.oembed(_id=1234567890)
#      |
#      |      # Update your status
#      |      t.statuses.update(
#      |          status="Using @sixohsix's sweet Python Twitter Tools.")
#      |
#      |      # Send a direct message
#      |      t.direct_messages.new(
#      |          user="billybob",
#      |          text="I think yer swell!")
#      |
#      |      # Get the members of tamtar's list "Things That Are Rad"
#      |      t.lists.members(owner_screen_name="tamtar", slug="things-that-are-rad")
#      |
#      |      # An *optional* `_timeout` parameter can also be used for API
#      |      # calls which take much more time than normal or twitter stops
#      |      # responding for some reason:
#      |      t.users.lookup(
#      |          screen_name=','.join(A_LIST_OF_100_SCREEN_NAMES),             _timeout=1)
#      |
#      |      # Overriding Method: GET/POST
#      |      # you should not need to use this method as this library properly
#      |      # detects whether GET or POST should be used, Nevertheless
#      |      # to force a particular method, use `_method`
#      |      t.statuses.oembed(_id=1234567890, _method='GET')
#      |
#      |      # Send images along with your tweets:
#      |      # - first just read images from the web or from files the regular way:
#      |      with open("example.png", "rb") as imagefile:
#      |          imagedata = imagefile.read()
#      |      # - then upload medias one by one on Twitter's dedicated server
#      |      #   and collect each one's id:
#      |      t_up = Twitter(domain='upload.twitter.com',
#      |          auth=OAuth(token, token_key, con_secret, con_secret_key))
#      |      id_img1 = t_up.media.upload(media=imagedata)["media_id_string"]
#      |      id_img2 = t_up.media.upload(media=imagedata)["media_id_string"]
#      |
#      |      # - finally send your tweet with the list of media ids:
#      |      t.statuses.update(status="PTT ★", media_ids=",".join([id_img1, id_img2]))
#      |
#      |      # Or send a tweet with an image (or set a logo/banner similarily)
#      |      # using the old deprecated method that will probably disappear some day
#      |      params = {"media[]": imagedata, "status": "PTT ★"}
#      |      # Or for an image encoded as base64:
#      |      params = {"media[]": base64_image, "status": "PTT ★", "_base64": True}
#      |      t.statuses.update_with_media(**params)
#      |
#      |
#      |
#      |  Searching Twitter::
#      |
#      |      # Search for the latest tweets about #pycon
#      |      t.search.tweets(q="#pycon")
#      |
#      |
#      |  Using the data returned
#      |  -----------------------
#      |
#      |  Twitter API calls return decoded JSON. This is converted into
#      |  a bunch of Python lists, dicts, ints, and strings. For example::
#      |
#      |      x = twitter.statuses.home_timeline()
#      |
#      |      # The first 'tweet' in the timeline
#      |      x[0]
#      |
#      |      # The screen name of the user who wrote the first 'tweet'
#      |      x[0]['user']['screen_name']
#      |
#      |
#      |  Getting raw XML data
#      |  --------------------
#      |
#      |  If you prefer to get your Twitter data in XML format, pass
#      |  format="xml" to the Twitter object when you instantiate it::
#      |
#      |      twitter = Twitter(format="xml")
#      |
#      |  The output will not be parsed in any way. It will be a raw string
#      |  of XML.
#      |
#      |  Method resolution order:
#      |      Twitter
#      |      TwitterCall
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, format='json', domain='api.twitter.com', secure=True, auth=None, api_version=<class 'twitter.api._DEFAULT'>, retry=False)
#      |      Create a new twitter API connector.
#      |
#      |      Pass an `auth` parameter to use the credentials of a specific
#      |      user. Generally you'll want to pass an `OAuth`
#      |      instance::
#      |
#      |          twitter = Twitter(auth=OAuth(
#      |                  token, token_secret, consumer_key, consumer_secret))
#      |
#      |
#      |      `domain` lets you change the domain you are connecting. By
#      |      default it's `api.twitter.com`.
#      |
#      |      If `secure` is False you will connect with HTTP instead of
#      |      HTTPS.
#      |
#      |      `api_version` is used to set the base uri. By default it's
#      |      '1.1'.
#      |
#      |      If `retry` is True, API rate limits will automatically be
#      |      handled by waiting until the next reset, as indicated by
#      |      the X-Rate-Limit-Reset HTTP header. If retry is an integer,
#      |      it defines the number of retries attempted.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from TwitterCall:
#      |
#      |  __call__(self, **kwargs)
#      |      Call self as a function.
#      |
#      |  __getattr__(self, k)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from TwitterCall:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from TwitterCall:
#      |
#      |  TWITTER_UNAVAILABLE_WAIT = 30
#
#     class TwitterError(builtins.Exception)
#      |  Base Exception thrown by the Twitter object when there is a
#      |  general error interacting with the API.
#      |
#      |  Method resolution order:
#      |      TwitterError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class TwitterHTTPError(TwitterError)
#      |  Exception thrown by the Twitter object when there is an
#      |  HTTP error interacting with twitter.com.
#      |
#      |  Method resolution order:
#      |      TwitterHTTPError
#      |      TwitterError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, e, uri, format, uriparts)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __str__(self)
#      |      Return str(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from TwitterError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class TwitterResponse(builtins.object)
#      |  Response from a twitter request. Behaves like a list or a string
#      |  (depending on requested format) but it has a few other interesting
#      |  attributes.
#      |
#      |  `headers` gives you access to the response headers as an
#      |  httplib.HTTPHeaders instance. You can do
#      |  `response.headers.get('h')` to retrieve a header.
#      |
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  rate_limit_limit
#      |      The rate limit ceiling for that given request.
#      |
#      |  rate_limit_remaining
#      |      Remaining requests in the current rate-limit.
#      |
#      |  rate_limit_reset
#      |      Time in UTC epoch seconds when the rate limit will reset.
#
#     class TwitterStream(twitter.api.TwitterCall)
#      |  The TwitterStream object is an interface to the Twitter Stream
#      |  API. This can be used pretty much the same as the Twitter class
#      |  except the result of calling a method will be an iterator that
#      |  yields objects decoded from the stream. For example::
#      |
#      |      twitter_stream = TwitterStream(auth=OAuth(...))
#      |      iterator = twitter_stream.statuses.sample()
#      |
#      |      for tweet in iterator:
#      |          # ...do something with this tweet...
#      |
#      |  Per default the ``TwitterStream`` object uses
#      |  [public streams](https://dev.twitter.com/docs/streaming-apis/streams/public).
#      |  If you want to use one of the other
#      |  [streaming APIs](https://dev.twitter.com/docs/streaming-apis), specify the URL
#      |  manually:
#      |
#      |  - [Public streams](https://dev.twitter.com/docs/streaming-apis/streams/public): stream.twitter.com
#      |  - [User streams](https://dev.twitter.com/docs/streaming-apis/streams/user): userstream.twitter.com
#      |  - [Site streams](https://dev.twitter.com/docs/streaming-apis/streams/site): sitestream.twitter.com
#      |
#      |  Note that you require the proper
#      |  [permissions](https://dev.twitter.com/docs/application-permission-model) to
#      |  access these streams. E.g. for direct messages your
#      |  [application](https://dev.twitter.com/apps) needs the "Read, Write & Direct
#      |  Messages" permission.
#      |
#      |  The following example demonstrates how to retrieve all new direct messages
#      |  from the user stream::
#      |
#      |      auth = OAuth(
#      |          consumer_key='[your consumer key]',
#      |          consumer_secret='[your consumer secret]',
#      |          token='[your token]',
#      |          token_secret='[your token secret]'
#      |      )
#      |      twitter_userstream = TwitterStream(auth=auth, domain='userstream.twitter.com')
#      |      for msg in twitter_userstream.user():
#      |          if 'direct_message' in msg:
#      |              print msg['direct_message']['text']
#      |
#      |  The iterator will yield until the TCP connection breaks. When the
#      |  connection breaks, the iterator yields `{'hangup': True}`, and
#      |  raises `StopIteration` if iterated again.
#      |
#      |  Similarly, if the stream does not produce heartbeats for more than
#      |  90 seconds, the iterator yields `{'hangup': True,
#      |  'heartbeat_timeout': True}`, and raises `StopIteration` if
#      |  iterated again.
#      |
#      |  The `timeout` parameter controls the maximum time between
#      |  yields. If it is nonzero, then the iterator will yield either
#      |  stream data or `{'timeout': True}` within the timeout period. This
#      |  is useful if you want your program to do other stuff in between
#      |  waiting for tweets.
#      |
#      |  The `block` parameter sets the stream to be fully non-blocking. In
#      |  this mode, the iterator always yields immediately. It returns
#      |  stream data, or `None`. Note that `timeout` supercedes this
#      |  argument, so it should also be set `None` to use this mode.
#      |
#      |  Method resolution order:
#      |      TwitterStream
#      |      twitter.api.TwitterCall
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, domain='stream.twitter.com', secure=True, auth=None, api_version='1.1', block=True, timeout=None, heartbeat_timeout=90.0)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from twitter.api.TwitterCall:
#      |
#      |  __call__(self, **kwargs)
#      |      Call self as a function.
#      |
#      |  __getattr__(self, k)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from twitter.api.TwitterCall:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from twitter.api.TwitterCall:
#      |
#      |  TWITTER_UNAVAILABLE_WAIT = 30
#
#     class UserPassAuth(Auth)
#      |  Basic auth authentication using email/username and
#      |  password. Deprecated.
#      |
#      |  Method resolution order:
#      |      UserPassAuth
#      |      Auth
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, username, password)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  encode_params(self, base_url, method, params)
#      |      Encodes parameters for a request suitable for including in a URL
#      |      or POST body.  This method may also add new params to the request
#      |      if required by the authentication scheme in use.
#      |
#      |  generate_headers(self)
#      |      Generates headers which should be added to the request if required
#      |      by the authentication scheme in use.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Auth:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     oauth2_dance(consumer_key, consumer_secret, token_filename=None)
#         Perform the OAuth2 dance to transform a consumer key and secret into a
#         bearer token.
#
#         If a token_filename is given, the bearer token will be written to
#         the file.
#
#     oauth_dance(app_name, consumer_key, consumer_secret, token_filename=None)
#         Perform the OAuth dance with some command-line prompts. Return the
#         oauth_token and oauth_token_secret.
#
#         Provide the name of your app in `app_name`, your consumer_key, and
#         consumer_secret. This function will open a web browser to let the
#         user allow your app to access their Twitter account. PIN
#         authentication is used.
#
#         If a token_filename is given, the oauth tokens will be written to
#         the file.
#
#     read_bearer_token_file(filename)
#         Read a token file and return the oauth2 bearer token.
#
#     read_token_file(filename)
#         Read a token file and return the oauth token and oauth token secret.
#
#     write_bearer_token_file(filename, oauth2_bearer_token)
#         Write a token file to hold the oauth2 bearer token.
#
#     write_token_file(filename, oauth_token, oauth_token_secret)
#         Write a token file to hold the oauth token and oauth token secret.
#
# DATA
#     __all__ = ['NoAuth', 'OAuth', 'OAuth2', 'oauth2_dance', 'oauth_dance',...
#
# FILE
#     /opt/conda/lib/python3.5/site-packages/twitter/__init__.py

# %% [markdown]
# Go ahead and take a look at the [twitter docs](https://dev.twitter.com/rest/public).

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print (world_trends)
print (us_trends)
# Out:
# [{'created_at': '2016-10-17T17:35:18Z', 'trends': [{'promoted_content': None, 'url': 'http://twitter.com/search?q=%23Joanne', 'query': '%23Joanne', 'tweet_volume': 94911, 'name': '#Joanne'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%81%D8%B6%D9%84_%D9%85%D8%B4%D8%B1%D9%88%D8%A8_%D8%A8%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85', 'query': '%23%D8%A7%D9%81%D8%B6%D9%84_%D9%85%D8%B4%D8%B1%D9%88%D8%A8_%D8%A8%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85', 'tweet_volume': None, 'name': '#افضل_مشروب_بالعالم'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23%D9%83%D9%85_%D8%B9%D9%86%D8%AF%D9%83_%D9%85%D8%B4%D8%A7%D9%87%D8%AF%D9%87_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D9%86%D8%A7%D8%A8', 'query': '%23%D9%83%D9%85_%D8%B9%D9%86%D8%AF%D9%83_%D9%85%D8%B4%D8%A7%D9%87%D8%AF%D9%87_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D9%86%D8%A7%D8%A8', 'tweet_volume': None, 'name': '#كم_عندك_مشاهده_في_السناب'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%88%D8%B5%D9%81_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87', 'query': '%23%D8%A7%D9%88%D8%B5%D9%81_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87', 'tweet_volume': 39284, 'name': '#اوصف_السعودي_بكلمه'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%832', 'query': '%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%832', 'tweet_volume': 62906, 'name': '#زد_رصيدك2'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Steven+Woolfe%22', 'query': '%22Steven+Woolfe%22', 'tweet_volume': None, 'name': 'Steven Woolfe'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22BELIEBERS+UNIDOS%22', 'query': '%22BELIEBERS+UNIDOS%22', 'tweet_volume': 39842, 'name': 'BELIEBERS UNIDOS'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22George+Zimmerman%22', 'query': '%22George+Zimmerman%22', 'tweet_volume': 15973, 'name': 'George Zimmerman'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Trump+TV%22', 'query': '%22Trump+TV%22', 'tweet_volume': 28857, 'name': 'Trump TV'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%E5%B8%AF%E3%81%AE%E3%83%95%E3%83%AC%E3%83%BC%E3%82%BA', 'query': '%E5%B8%AF%E3%81%AE%E3%83%95%E3%83%AC%E3%83%BC%E3%82%BA', 'tweet_volume': None, 'name': '帯のフレーズ'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%E4%BA%BA%E5%A6%BB10%E9%80%A3%E3%82%AC%E3%83%81%E3%83%A3', 'query': '%E4%BA%BA%E5%A6%BB10%E9%80%A3%E3%82%AC%E3%83%81%E3%83%A3', 'tweet_volume': None, 'name': '人妻10連ガチャ'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22R%C3%BCzgar%C4%B1n+Kalbi%22', 'query': '%22R%C3%BCzgar%C4%B1n+Kalbi%22', 'tweet_volume': None, 'name': 'Rüzgarın Kalbi'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23FelizLunes', 'query': '%23FelizLunes', 'tweet_volume': 62272, 'name': '#FelizLunes'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23PraVidaFicarBoaS%C3%B3Falta', 'query': '%23PraVidaFicarBoaS%C3%B3Falta', 'tweet_volume': 15094, 'name': '#PraVidaFicarBoaSóFalta'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23mondaymotivation', 'query': '%23mondaymotivation', 'tweet_volume': 134073, 'name': '#mondaymotivation'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23NationalPastaDay', 'query': '%23NationalPastaDay', 'tweet_volume': 17686, 'name': '#NationalPastaDay'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23%D9%83%D9%84%D9%86%D8%A7_%D8%B6%D8%AF_%D8%A7%D9%84%D8%AD%D8%A8', 'query': '%23%D9%83%D9%84%D9%86%D8%A7_%D8%B6%D8%AF_%D8%A7%D9%84%D8%AD%D8%A8', 'tweet_volume': 12237, 'name': '#كلنا_ضد_الحب'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23MorandiniLive', 'query': '%23MorandiniLive', 'tweet_volume': None, 'name': '#MorandiniLive'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23GBHeroesMCR', 'query': '%23GBHeroes ...
# [{'created_at': '2016-10-17T17:40:16Z', 'trends': [{'promoted_content': None, 'url': 'http://twitter.com/search?q=%23mondaymotivation', 'query': '%23mondaymotivation', 'tweet_volume': 135282, 'name': '#mondaymotivation'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23NationalPastaDay', 'query': '%23NationalPastaDay', 'tweet_volume': 17987, 'name': '#NationalPastaDay'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23MovieTitleToDescribeElection', 'query': '%23MovieTitleToDescribeElection', 'tweet_volume': 22900, 'name': '#MovieTitleToDescribeElection'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23MakeMeHateYouInOnePhrase', 'query': '%23MakeMeHateYouInOnePhrase', 'tweet_volume': 15249, 'name': '#MakeMeHateYouInOnePhrase'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%23FreeJulian', 'query': '%23FreeJulian', 'tweet_volume': 170290, 'name': '#FreeJulian'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22George+Zimmerman%22', 'query': '%22George+Zimmerman%22', 'tweet_volume': 16499, 'name': 'George Zimmerman'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Trump+TV%22', 'query': '%22Trump+TV%22', 'tweet_volume': 29374, 'name': 'Trump TV'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=Joanne', 'query': 'Joanne', 'tweet_volume': 136940, 'name': 'Joanne'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22To+the+First+Lady%22', 'query': '%22To+the+First+Lady%22', 'tweet_volume': None, 'name': 'To the First Lady'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Amy+Schumer%22', 'query': '%22Amy+Schumer%22', 'tweet_volume': 11921, 'name': 'Amy Schumer'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Come+to+Mama%22', 'query': '%22Come+to+Mama%22', 'tweet_volume': None, 'name': 'Come to Mama'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Diamond+Heart%22', 'query': '%22Diamond+Heart%22', 'tweet_volume': None, 'name': 'Diamond Heart'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22John+Wayne%22', 'query': '%22John+Wayne%22', 'tweet_volume': None, 'name': 'John Wayne'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22New+CNN%22', 'query': '%22New+CNN%22', 'tweet_volume': None, 'name': 'New CNN'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Azealia+Banks%22', 'query': '%22Azealia+Banks%22', 'tweet_volume': 18949, 'name': 'Azealia Banks'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Shepard+Smith%22', 'query': '%22Shepard+Smith%22', 'tweet_volume': None, 'name': 'Shepard Smith'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Angel+Down%22', 'query': '%22Angel+Down%22', 'tweet_volume': None, 'name': 'Angel Down'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Red+Dead%22', 'query': '%22Red+Dead%22', 'tweet_volume': 57494, 'name': 'Red Dead'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Amiya+Morris%22', 'query': '%22Amiya+Morris%22', 'tweet_volume': None, 'name': 'Amiya Morris'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Guantanamo+Diary%22', 'query': '%22Guantanamo+Diary%22', 'tweet_volume': None, 'name': 'Guantanamo Diary'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Rigging+the+Election+-+Video%22', 'query': '%22Rigging+the+Election+-+Video%22', 'tweet_volume': None, 'name': 'Rigging the Election - Video'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Carl+Icahn%22', 'query': '%22Carl+Icahn%22', 'tweet_volume': None, 'name': 'Carl Icahn'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22Ed+Orgeron%22', 'query': '%22Ed+Orgeron%22', 'tweet_volume': None, 'name': 'Ed Orgeron'}, {'promoted_content': None, 'url': 'http://twitter.com/search?q=%22CDT+de+Puerto+Nuevo%22', 'query': '%22CDT+de+Puerto+Nuevo%22', 'tw ...

# %% [markdown]
# ## Step 3. Displaying API responses as pretty-printed JSON

# %%
import json

print (json.dumps(world_trends, indent=1))
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "created_at": "2016-10-17T17:35:18Z",
#   "trends": [
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Joanne",
#     "query": "%23Joanne",
#     "tweet_volume": 94911,
#     "name": "#Joanne"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%81%D8%B6%D9%84_%D9%85%D8%B4%D8%B1%D9%88%D8%A8_%D8%A8%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85",
#     "query": "%23%D8%A7%D9%81%D8%B6%D9%84_%D9%85%D8%B4%D8%B1%D9%88%D8%A8_%D8%A8%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85",
#     "tweet_volume": null,
#     "name": "#\u0627\u0641\u0636\u0644_\u0645\u0634\u0631\u0648\u0628_\u0628\u0627\u0644\u0639\u0627\u0644\u0645"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%85_%D8%B9%D9%86%D8%AF%D9%83_%D9%85%D8%B4%D8%A7%D9%87%D8%AF%D9%87_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D9%86%D8%A7%D8%A8",
#     "query": "%23%D9%83%D9%85_%D8%B9%D9%86%D8%AF%D9%83_%D9%85%D8%B4%D8%A7%D9%87%D8%AF%D9%87_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D9%86%D8%A7%D8%A8",
#     "tweet_volume": null,
#     "name": "#\u0643\u0645_\u0639\u0646\u062f\u0643_\u0645\u0634\u0627\u0647\u062f\u0647_\u0641\u064a_\u0627\u0644\u0633\u0646\u0627\u0628"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%88%D8%B5%D9%81_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87",
#     "query": "%23%D8%A7%D9%88%D8%B5%D9%81_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87",
#     "tweet_volume": 39284,
#     "name": "#\u0627\u0648\u0635\u0641_\u0627\u0644\u0633\u0639\u0648\u062f\u064a_\u0628\u0643\u0644\u0645\u0647"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%832",
#     "query": "%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%832",
#     "tweet_volume": 62906,
#     "name": "#\u0632\u062f_\u0631\u0635\u064a\u062f\u06432"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Steven+Woolfe%22",
#     "query": "%22Steven+Woolfe%22",
#     "tweet_volume": null,
#     "name": "Steven Woolfe"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22BELIEBERS+UNIDOS%22",
#     "query": "%22BELIEBERS+UNIDOS%22",
#     "tweet_volume": 39842,
#     "name": "BELIEBERS UNIDOS"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22George+Zimmerman%22",
#     "query": "%22George+Zimmerman%22",
#     "tweet_volume": 15973,
#     "name": "George Zimmerman"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Trump+TV%22",
#     "query": "%22Trump+TV%22",
#     "tweet_volume": 28857,
#     "name": "Trump TV"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%E5%B8%AF%E3%81%AE%E3%83%95%E3%83%AC%E3%83%BC%E3%82%BA",
#     "query": "%E5%B8%AF%E3%81%AE%E3%83%95%E3%83%AC%E3%83%BC%E3%82%BA",
#     "tweet_volume": null,
#     "name": "\u5e2f\u306e\u30d5\u30ec\u30fc\u30ba"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%E4%BA%BA%E5%A6%BB10%E9%80%A3%E3%82%AC%E3%83%81%E3%83%A3",
#     "query": "%E4%BA%BA%E5%A6%BB10%E9%80%A3%E3%82%AC%E3%83%81%E3%83%A3",
#     "tweet_volume": null,
#     "name": "\u4eba\u59bb10\u9023\u30ac\u30c1\u30e3"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22R%C3%BCzgar%C4%B1n+Kalbi%22",
#     "query": "%22R%C3%BCzgar%C4%B1n+Kalbi%22",
#     "tweet_volume": null,
#     "name": "R\u00fczgar\u0131n Kalbi"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23FelizLunes",
#     "query": "%23FelizLunes",
#     "tweet_volume": 62272,
#     "name": "#FelizLunes"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23PraVidaFicarBoaS%C3%B3Falta",
#     "query": "%23PraVidaFicarBoaS%C3%B3Falta",
#     "tweet_volume": 15094,
#     "name": "#PraVidaFicarBoaS\u00f3Falta"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23mondaymotivation",
#     "query": "%23mondaymotivation",
#     "tweet_volume": 134073,
#     "name": "#mondaymotivation"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23NationalPastaDay",
#     "query": "%23NationalPastaDay",
#     "tweet_volume": 17686,
#     "name": "#NationalPastaDay"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D9%86%D8%A7_%D8%B6%D8%AF_%D8%A7%D9%84%D8%AD%D8%A8",
#     "query": "%23%D9%83%D9%84%D9%86%D8%A7_%D8%B6%D8%AF_%D8%A7%D9%84%D8%AD%D8%A8",
#     "tweet_volume": 12237,
#     "name": "#\u0643\u0644\u0646\u0627_\u0636\u062f_\u0627\u0644\u062d\u0628"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MorandiniLive",
#     "query": "%23MorandiniLive",
#     "tweet_volume": null,
#     "name": "#MorandiniLive"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23GBHeroesMCR",
#     "query": "%23GBHeroesMCR",
#     "tweet_volume": 13840,
#     "name": "#GBHeroesMCR"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23EdirnedenMusulaYeniT%C3%BCrkiye",
#     "query": "%23EdirnedenMusulaYeniT%C3%BCrkiye",
#     "tweet_volume": null,
#     "name": "#EdirnedenMusulaYeniT\u00fcrkiye"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23i%C3%A7erdeyim",
#     "query": "%23i%C3%A7erdeyim",
#     "tweet_volume": null,
#     "name": "#i\u00e7erdeyim"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MakeMeHateYouInOnePhrase",
#     "query": "%23MakeMeHateYouInOnePhrase",
#     "tweet_volume": 14799,
#     "name": "#MakeMeHateYouInOnePhrase"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B9%D9%81%D9%88%D8%A7_%D9%88%D8%B2%D9%8A%D8%B1_%D8%A7%D9%84%D8%A7%D8%AA%D8%B5%D8%A7%D9%84%D8%A7%D8%AA",
#     "query": "%23%D8%A7%D8%B9%D9%81%D9%88%D8%A7_%D9%88%D8%B2%D9%8A%D8%B1_%D8%A7%D9%84%D8%A7%D8%AA%D8%B5%D8%A7%D9%84%D8%A7%D8%AA",
#     "tweet_volume": 28932,
#     "name": "#\u0627\u0639\u0641\u0648\u0627_\u0648\u0632\u064a\u0631_\u0627\u0644\u0627\u062a\u0635\u0627\u0644\u0627\u062a"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MovieTitleToDescribeElection",
#     "query": "%23MovieTitleToDescribeElection",
#     "tweet_volume": 22691,
#     "name": "#MovieTitleToDescribeElection"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%EC%B5%9C%EC%95%A0%EC%BA%90_%EB%8C%80%EC%82%AC_%EB%8B%B9%EC%9E%A5_%EB%96%A0%EC%98%A4%EB%A5%B8%EB%8C%80%EB%A1%9C_%EC%A0%81%EC%96%B4%EB%B4%90",
#     "query": "%23%EC%B5%9C%EC%95%A0%EC%BA%90_%EB%8C%80%EC%82%AC_%EB%8B%B9%EC%9E%A5_%EB%96%A0%EC%98%A4%EB%A5%B8%EB%8C%80%EB%A1%9C_%EC%A0%81%EC%96%B4%EB%B4%90",
#     "tweet_volume": null,
#     "name": "#\ucd5c\uc560\uce90_\ub300\uc0ac_\ub2f9\uc7a5_\ub5a0\uc624\ub978\ub300\ub85c_\uc801\uc5b4\ubd10"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23OneDitection",
#     "query": "%23OneDitection",
#     "tweet_volume": 23597,
#     "name": "#OneDitection"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23PuebloDignificado",
#     "query": "%23PuebloDignificado",
#     "tweet_volume": 24118,
#     "name": "#PuebloDignificado"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23VUZURichKids",
#     "query": "%23VUZURichKids",
#     "tweet_volume": null,
#     "name": "#VUZURichKids"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%E4%B8%80%E7%9E%AC%E3%81%A7%E3%83%90%E3%83%AC%E3%82%8B%E5%98%98%E3%82%92%E4%BB%98%E3%81%91",
#     "query": "%23%E4%B8%80%E7%9E%AC%E3%81%A7%E3%83%90%E3%83%AC%E3%82%8B%E5%98%98%E3%82%92%E4%BB%98%E3%81%91",
#     "tweet_volume": 43308,
#     "name": "#\u4e00\u77ac\u3067\u30d0\u30ec\u308b\u5618\u3092\u4ed8\u3051"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MustafaSandalHepsiA%C5%9Fktan",
#     "query": "%23MustafaSandalHepsiA%C5%9Fktan",
#     "tweet_volume": null,
#     "name": "#MustafaSandalHepsiA\u015fktan"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D8%AA%D9%8A%D9%85_%D8%A7%D9%84%D9%82%D9%85%D9%87_%D9%88%D8%A7%D9%84%D9%81%D9%88%D9%84%D9%88%D8%B1%D8%B2_%D8%A8%D8%A7%D9%84%D8%AD%D8%A8",
#     "query": "%23%D8%AA%D9%8A%D9%85_%D8%A7%D9%84%D9%82%D9%85%D9%87_%D9%88%D8%A7%D9%84%D9%81%D9%88%D9%84%D9%88%D8%B1%D8%B2_%D8%A8%D8%A7%D9%84%D8%AD%D8%A8",
#     "tweet_volume": 100767,
#     "name": "#\u062a\u064a\u0645_\u0627\u0644\u0642\u0645\u0647_\u0648\u0627\u0644\u0641\u0648\u0644\u0648\u0631\u0632_\u0628\u0627\u0644\u062d\u0628"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23DiaDeLaLealtadPeronista",
#     "query": "%23DiaDeLaLealtadPeronista",
#     "tweet_volume": 20665,
#     "name": "#DiaDeLaLealtadPeronista"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23SiemprePasaEnLunes",
#     "query": "%23SiemprePasaEnLunes",
#     "tweet_volume": null,
#     "name": "#SiemprePasaEnLunes"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Amoquellepersoneche",
#     "query": "%23Amoquellepersoneche",
#     "tweet_volume": null,
#     "name": "#Amoquellepersoneche"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23727TourParis",
#     "query": "%23727TourParis",
#     "tweet_volume": 11832,
#     "name": "#727TourParis"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MyFirstCarIn3Words",
#     "query": "%23MyFirstCarIn3Words",
#     "tweet_volume": null,
#     "name": "#MyFirstCarIn3Words"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23BenHepDemi%C5%9Fimdir",
#     "query": "%23BenHepDemi%C5%9Fimdir",
#     "tweet_volume": null,
#     "name": "#BenHepDemi\u015fimdir"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23ChaiWala",
#     "query": "%23ChaiWala",
#     "tweet_volume": null,
#     "name": "#ChaiWala"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D9%84%D9%8A%D9%81%D8%B1%D8%A8%D9%88%D9%84_%D9%85%D8%A7%D9%86%D8%B4%D8%B3%D8%AA%D8%B1",
#     "query": "%23%D9%84%D9%8A%D9%81%D8%B1%D8%A8%D9%88%D9%84_%D9%85%D8%A7%D9%86%D8%B4%D8%B3%D8%AA%D8%B1",
#     "tweet_volume": null,
#     "name": "#\u0644\u064a\u0641\u0631\u0628\u0648\u0644_\u0645\u0627\u0646\u0634\u0633\u062a\u0631"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23HoyMeDieronGanasDe",
#     "query": "%23HoyMeDieronGanasDe",
#     "tweet_volume": null,
#     "name": "#HoyMeDieronGanasDe"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23FreeJulian",
#     "query": "%23FreeJulian",
#     "tweet_volume": 169008,
#     "name": "#FreeJulian"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23AllupEnVladimirala1",
#     "query": "%23AllupEnVladimirala1",
#     "tweet_volume": null,
#     "name": "#AllupEnVladimirala1"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23olypao",
#     "query": "%23olypao",
#     "tweet_volume": null,
#     "name": "#olypao"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23DearZindagi",
#     "query": "%23DearZindagi",
#     "tweet_volume": 14717,
#     "name": "#DearZindagi"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23FofocandoNoSBT",
#     "query": "%23FofocandoNoSBT",
#     "tweet_volume": null,
#     "name": "#FofocandoNoSBT"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%D9%86%D8%A8%D9%8A_%D8%A8%D8%A7%D8%B1_%D8%A7%D8%B3%D9%84%D8%A7%D9%85%D9%8A%D9%A1",
#     "query": "%23%D9%86%D8%A8%D9%8A_%D8%A8%D8%A7%D8%B1_%D8%A7%D8%B3%D9%84%D8%A7%D9%85%D9%8A%D9%A1",
#     "tweet_volume": null,
#     "name": "#\u0646\u0628\u064a_\u0628\u0627\u0631_\u0627\u0633\u0644\u0627\u0645\u064a\u0661"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23%C3%96%C4%9FretmeneEme%C4%9FiniVer",
#     "query": "%23%C3%96%C4%9FretmeneEme%C4%9FiniVer",
#     "tweet_volume": 14406,
#     "name": "#\u00d6\u011fretmeneEme\u011finiVer"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23ConAbortoNoCuentesConMiVoto",
#     "query": "%23ConAbortoNoCuentesConMiVoto",
#     "tweet_volume": null,
#     "name": "#ConAbortoNoCuentesConMiVoto"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23CookingSchmovies",
#     "query": "%23CookingSchmovies",
#     "tweet_volume": null,
#     "name": "#CookingSchmovies"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23DiadelasEscritoras",
#     "query": "%23DiadelasEscritoras",
#     "tweet_volume": 27456,
#     "name": "#DiadelasEscritoras"
#    }
#   ],
#   "as_of": "2016-10-17T17:42:47Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
# [
#  {
#   "created_at": "2016-10-17T17:40:16Z",
#   "trends": [
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23mondaymotivation",
#     "query": "%23mondaymotivation",
#     "tweet_volume": 135282,
#     "name": "#mondaymotivation"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23NationalPastaDay",
#     "query": "%23NationalPastaDay",
#     "tweet_volume": 17987,
#     "name": "#NationalPastaDay"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MovieTitleToDescribeElection",
#     "query": "%23MovieTitleToDescribeElection",
#     "tweet_volume": 22900,
#     "name": "#MovieTitleToDescribeElection"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MakeMeHateYouInOnePhrase",
#     "query": "%23MakeMeHateYouInOnePhrase",
#     "tweet_volume": 15249,
#     "name": "#MakeMeHateYouInOnePhrase"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23FreeJulian",
#     "query": "%23FreeJulian",
#     "tweet_volume": 170290,
#     "name": "#FreeJulian"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22George+Zimmerman%22",
#     "query": "%22George+Zimmerman%22",
#     "tweet_volume": 16499,
#     "name": "George Zimmerman"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Trump+TV%22",
#     "query": "%22Trump+TV%22",
#     "tweet_volume": 29374,
#     "name": "Trump TV"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=Joanne",
#     "query": "Joanne",
#     "tweet_volume": 136940,
#     "name": "Joanne"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22To+the+First+Lady%22",
#     "query": "%22To+the+First+Lady%22",
#     "tweet_volume": null,
#     "name": "To the First Lady"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Amy+Schumer%22",
#     "query": "%22Amy+Schumer%22",
#     "tweet_volume": 11921,
#     "name": "Amy Schumer"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Come+to+Mama%22",
#     "query": "%22Come+to+Mama%22",
#     "tweet_volume": null,
#     "name": "Come to Mama"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Diamond+Heart%22",
#     "query": "%22Diamond+Heart%22",
#     "tweet_volume": null,
#     "name": "Diamond Heart"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22John+Wayne%22",
#     "query": "%22John+Wayne%22",
#     "tweet_volume": null,
#     "name": "John Wayne"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22New+CNN%22",
#     "query": "%22New+CNN%22",
#     "tweet_volume": null,
#     "name": "New CNN"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Azealia+Banks%22",
#     "query": "%22Azealia+Banks%22",
#     "tweet_volume": 18949,
#     "name": "Azealia Banks"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Shepard+Smith%22",
#     "query": "%22Shepard+Smith%22",
#     "tweet_volume": null,
#     "name": "Shepard Smith"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Angel+Down%22",
#     "query": "%22Angel+Down%22",
#     "tweet_volume": null,
#     "name": "Angel Down"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Red+Dead%22",
#     "query": "%22Red+Dead%22",
#     "tweet_volume": 57494,
#     "name": "Red Dead"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Amiya+Morris%22",
#     "query": "%22Amiya+Morris%22",
#     "tweet_volume": null,
#     "name": "Amiya Morris"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Guantanamo+Diary%22",
#     "query": "%22Guantanamo+Diary%22",
#     "tweet_volume": null,
#     "name": "Guantanamo Diary"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Rigging+the+Election+-+Video%22",
#     "query": "%22Rigging+the+Election+-+Video%22",
#     "tweet_volume": null,
#     "name": "Rigging the Election - Video"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Carl+Icahn%22",
#     "query": "%22Carl+Icahn%22",
#     "tweet_volume": null,
#     "name": "Carl Icahn"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Ed+Orgeron%22",
#     "query": "%22Ed+Orgeron%22",
#     "tweet_volume": null,
#     "name": "Ed Orgeron"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22CDT+de+Puerto+Nuevo%22",
#     "query": "%22CDT+de+Puerto+Nuevo%22",
#     "tweet_volume": null,
#     "name": "CDT de Puerto Nuevo"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Motown+Museum%22",
#     "query": "%22Motown+Museum%22",
#     "tweet_volume": null,
#     "name": "Motown Museum"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Jolly+Fish+Press%22",
#     "query": "%22Jolly+Fish+Press%22",
#     "tweet_volume": null,
#     "name": "Jolly Fish Press"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Incite+Violence%22",
#     "query": "%22Incite+Violence%22",
#     "tweet_volume": 18983,
#     "name": "Incite Violence"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%22Pray+4+Me%22",
#     "query": "%22Pray+4+Me%22",
#     "tweet_volume": null,
#     "name": "Pray 4 Me"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23MyFirstCarIn3Words",
#     "query": "%23MyFirstCarIn3Words",
#     "tweet_volume": null,
#     "name": "#MyFirstCarIn3Words"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23LArain",
#     "query": "%23LArain",
#     "tweet_volume": null,
#     "name": "#LArain"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23CookingSchmovies",
#     "query": "%23CookingSchmovies",
#     "tweet_volume": null,
#     "name": "#CookingSchmovies"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23BossDay",
#     "query": "%23BossDay",
#     "tweet_volume": null,
#     "name": "#BossDay"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Under30Summit",
#     "query": "%23Under30Summit",
#     "tweet_volume": null,
#     "name": "#Under30Summit"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23DPSEPSC",
#     "query": "%23DPSEPSC",
#     "tweet_volume": null,
#     "name": "#DPSEPSC"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23jbfconf2016",
#     "query": "%23jbfconf2016",
#     "tweet_volume": null,
#     "name": "#jbfconf2016"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23KevinCanWait",
#     "query": "%23KevinCanWait",
#     "tweet_volume": null,
#     "name": "#KevinCanWait"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23EndPoverty",
#     "query": "%23EndPoverty",
#     "tweet_volume": 13770,
#     "name": "#EndPoverty"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23heweb16",
#     "query": "%23heweb16",
#     "tweet_volume": null,
#     "name": "#heweb16"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23JunkinsFire",
#     "query": "%23JunkinsFire",
#     "tweet_volume": null,
#     "name": "#JunkinsFire"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23GartnerSYM",
#     "query": "%23GartnerSYM",
#     "tweet_volume": 10880,
#     "name": "#GartnerSYM"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23My5WordHorrorNovel",
#     "query": "%23My5WordHorrorNovel",
#     "tweet_volume": null,
#     "name": "#My5WordHorrorNovel"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23VR2020",
#     "query": "%23VR2020",
#     "tweet_volume": null,
#     "name": "#VR2020"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Outnumbered",
#     "query": "%23Outnumbered",
#     "tweet_volume": null,
#     "name": "#Outnumbered"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23Barbie",
#     "query": "%23Barbie",
#     "tweet_volume": null,
#     "name": "#Barbie"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23congratsliam",
#     "query": "%23congratsliam",
#     "tweet_volume": null,
#     "name": "#congratsliam"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23JaneTheVirgin",
#     "query": "%23JaneTheVirgin",
#     "tweet_volume": null,
#     "name": "#JaneTheVirgin"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23usglcFL",
#     "query": "%23usglcFL",
#     "tweet_volume": null,
#     "name": "#usglcFL"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23VictoryMonday",
#     "query": "%23VictoryMonday",
#     "tweet_volume": null,
#     "name": "#VictoryMonday"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23PAKvWI",
#     "query": "%23PAKvWI",
#     "tweet_volume": 12344,
#     "name": "#PAKvWI"
#    },
#    {
#     "promoted_content": null,
#     "url": "http://twitter.com/search?q=%23frantasticmonday",
#     "query": "%23frantasticmonday",
#     "tweet_volume": null,
#     "name": "#frantasticmonday"
#    }
#   ],
#   "as_of": "2016-10-17T17:42:47Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# Take a look at the [api docs](https://dev.twitter.com/rest/reference/get/trends/place) for the /trends/place call made above.

# %% [markdown]
# ## Step 4. Collecting search results for a targeted hashtag.

# %%
# Import unquote to prevent url encoding errors in next_results
#from urllib3 import unquote

#This can be any trending topic, but let's focus on a hashtag that is relevant to the class. 
q = '#analytics' 

count = 100

# See https://dev.twitter.com/rest/reference/get/search/tweets
search_results = twitter_api.search.tweets(q=q, count=count)

#This selects out 
statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor
for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
        print ("next_results", next_results)
    except: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    print (kwargs)
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print (json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# next_results ?max_id=788092679632646149&q=%23analytics&count=100&include_entities=1
# {'include_entities': '1', 'count': '100', 'q': '%23analytics', 'max_id': '788092679632646149'}
# Length of statuses 200
# next_results ?max_id=788088954318888960&q=%2523analytics&count=100&include_entities=1
# {'include_entities': '1', 'count': '100', 'q': '%2523analytics', 'max_id': '788088954318888960'}
# Length of statuses 200
# {
#  "entities": {
#   "urls": [
#    {
#     "indices": [
#      76,
#      99
#     ],
#     "url": "https://t.co/0Z9igOItTg",
#     "display_url": "klou.tt/1xnyi0jcrbm1j",
#     "expanded_url": "http://klou.tt/1xnyi0jcrbm1j"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      25,
#      35
#     ],
#     "text": "Analytics"
#    },
#    {
#     "indices": [
#      50,
#      73
#     ],
#     "text": "ArtificialIntelligence"
#    }
#   ],
#   "symbols": [],
#   "user_mentions": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "retweet_count": 0,
#  "id_str": "788097057852534784",
#  "place": null,
#  "coordinates": null,
#  "lang": "en",
#  "source": "<a href=\"http://klout.com\" rel=\"nofollow\">Post with Klout</a>",
#  "favorite_count": 0,
#  "favorited": false,
#  "created_at": "Mon Oct 17 19:19:15 +0000 2016",
#  "contributors": null,
#  "geo": null,
#  "truncated": false,
#  "retweeted": false,
#  "user": {
#   "verified": false,
#   "geo_enabled": false,
#   "location": "France",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "contributors_enabled": false,
#   "profile_use_background_image": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1694411060/jmc_normal.JPG",
#   "time_zone": null,
#   "id_str": "36387920",
#   "default_profile_image": false,
#   "lang": "en",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1694411060/jmc_normal.JPG",
#   "is_translator": false,
#   "favourites_count": 104,
#   "following": false,
#   "statuses_count": 6094,
#   "description": "Knowledge Manager @AT_Internet",
#   "created_at": "Wed Apr 29 15:41:39 +0000 2009",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "url": null,
#   "profile_text_color": "333333",
#   "profile_background_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "translator_type": "none",
#   "notifications": false,
#   "name": "Jean-Marie Camiade",
#   "followers_count": 2037,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "is_translation_enabled": false,
#   "profile_link_color": "0084B4",
#   "protected": false,
#   "has_extended_profile": false,
#   "utc_offset": null,
#   "screen_name": "JMCamiade",
#   "default_profile": true,
#   "follow_request_sent": false,
#   "friends_count": 1688,
#   "profile_sidebar_border_color": "C0DEED",
#   "id": 36387920,
#   "listed_count": 1663,
#   "profile_background_tile": false
#  },
#  "id": 788097057852534784,
#  "in_reply_to_status_id": null,
#  "in_reply_to_user_id": null,
#  "possibly_sensitive": false,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id_str": null,
#  "text": "Virtuous Machines -- How #Analytics Will Underpin #ArtificialIntelligence - https://t.co/0Z9igOItTg",
#  "is_quote_status": false
# }

# %%
#Print several
print (json.dumps(statuses[0:5], indent=1))
# Out:
#   File "<ipython-input-17-2b923ab02010>", line 2
#     print json.dumps(statuses[0:5], indent=1)
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Step 5. Extracting text, screen names, and hashtags from tweets

# %%
#We can access an individual tweet like so:
statuses[1]['text']
# Out:
# 'RT @compuware: Is It Time to Organize Your Mainframe Toolbox? via @Andrew_D_Hocker  @LinkedIn https://t.co/N7qGNxx7AB #IBMz #analytics'

# %%
statuses[1]['entities']
# Out:
# {'hashtags': [{'indices': [118, 123], 'text': 'IBMz'},
#   {'indices': [124, 134], 'text': 'analytics'}],
#  'symbols': [],
#  'urls': [{'display_url': 'hubs.ly/H04MT0F0',
#    'expanded_url': 'http://hubs.ly/H04MT0F0',
#    'indices': [94, 117],
#    'url': 'https://t.co/N7qGNxx7AB'}],
#  'user_mentions': [{'id': 14296525,
#    'id_str': '14296525',
#    'indices': [3, 13],
#    'name': 'Compuware',
#    'screen_name': 'compuware'},
#   {'id': 788049133458296832,
#    'id_str': '788049133458296832',
#    'indices': [66, 82],
#    'name': 'Andrew Hocker',
#    'screen_name': 'Andrew_D_Hocker'},
#   {'id': 13058772,
#    'id_str': '13058772',
#    'indices': [84, 93],
#    'name': 'LinkedIn',
#    'screen_name': 'LinkedIn'}]}

# %%
#notice the nested relationships.  We have to take notice of this to further access the data.
statuses[1]['entities']['hashtags']
# Out:
# [{'indices': [118, 123], 'text': 'IBMz'},
#  {'indices': [124, 134], 'text': 'analytics'}]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

urls = [ url['url'] 
             for status in statuses
                 for url in status['entities']['urls'] ]



# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1)) 
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "Virtuous Machines -- How #Analytics Will Underpin #ArtificialIntelligence - https://t.co/0Z9igOItTg",
#  "RT @compuware: Is It Time to Organize Your Mainframe Toolbox? via @Andrew_D_Hocker  @LinkedIn https://t.co/N7qGNxx7AB #IBMz #analytics",
#  "RT @IBMIBV How can a #datascientist help transform your #analytics? Learn more in this #IBVstudy: https://t.co/f6HrqrLuHB",
#  "RT @DnBUS: We are proud to have had many successful #analytics projects\u2013learn more about the stories &amp; stats behind these wins. https://t.c\u2026",
#  "https://t.co/aWH3qw9Gnx is For Sale  #icomms #tools #IoT #ux #onclick #Networking #Conference #Conferences #Network #BigData #Analytics #B2B"
# ]
# [
#  "compuware",
#  "Andrew_D_Hocker",
#  "LinkedIn",
#  "IBMIBV",
#  "DnBUS"
# ]
# [
#  "Analytics",
#  "ArtificialIntelligence",
#  "IBMz",
#  "analytics",
#  "datascientist"
# ]
# [
#  "Virtuous",
#  "Machines",
#  "--",
#  "How",
#  "#Analytics"
# ]

# %% [markdown]
# ## Step 6. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:10]) # top 10, "\n")
# Out:
# [('#analytics', 100), ('RT', 96), ('#Analytics', 82), ('to', 51), ('for', 42), ('#BigData', 39), ('the', 39), ('and', 36), ('in', 34), ('via', 31)]
# [('compuware', 17), ('LinkedIn', 17), ('Andrew_D_Hocker', 17), ('Informatica', 11), ('SnowflakeDB', 8), ('TwitterDev', 3), ('DeloitteBA', 3), ('TamaraMcCleary', 2), ('eMarketer', 2), ('payoda', 2)]
# [('analytics', 109), ('Analytics', 89), ('BigData', 40), ('Data', 17), ('IBMz', 17), ('data', 13), ('Cloud', 12), ('Google', 8), ('CloudAnalytics', 7), ('GoogleAnalytics', 7)]
